# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarthak20Shukla/Machine-Learning/blob/master/linearregressionsinglevariable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
path="/content/drive/MyDrive/ml/homeprices.csv"
df= pd.read_csv(path)
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(usd)')
plt.scatter(df.area,df.price,color='red',marker='+')
